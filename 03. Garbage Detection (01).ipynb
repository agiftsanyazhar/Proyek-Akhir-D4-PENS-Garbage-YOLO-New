# %%
from ultralytics import YOLO
import cv2
import math
from collections import defaultdict
import numpy as np

# %% [markdown]
# ## Without Track

# %%
# # For Webcam
# cap = cv2.VideoCapture(0)

# For Video
input_video_path = "footage/testing/cctv/not littering/trim_trimmed_152.mp4"
cap = cv2.VideoCapture(input_video_path)

# %%
# Initialize the YOLO model
model = YOLO("runs/train/train7/weights/best.pt")

# %%
# Define class names
classNames = [
    "Others",
    "Plastic",
    "Straw",
    "Paper",
    "Tissue",
    "Bottle",
    "Beverage Carton Box",
    "Cigarette Pack",
    "Carton",
    "Food Container",
]

# Define colors for each class (adjust as needed)
class_colors = {
    "Others": (255, 0, 0),
    "Plastic": (255, 0, 128),
    "Paper": (179, 0, 255),
    "Straw": (255, 0, 255),
    "Tissue": (0, 255, 0),
    "Bottle": (0, 255, 255),
    "Beverage Carton Box": (0, 128, 255),
    "Cigarette Pack": (0, 0, 255),
    "Carton": (255, 255, 0),
    "Food Container": (255, 128, 0),
}

# %%
while True:
    # Read a frame from the video
    success, img = cap.read()
    if not success:
        break

    # Perform object detection
    results = model(img, stream=True)

    # Process each result
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # Extract box coordinates and confidence
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            conf = math.ceil((box.conf[0] * 100)) / 100
            cls = int(box.cls[0])

            # Ensure the class index is within the range of classNames
            if cls < len(classNames):
                currentClass = classNames[cls]

                color = class_colors[currentClass]
                cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
                text = f"{currentClass} {conf}"
                cv2.putText(
                    img,
                    text,
                    (max(0, x1), max(35, y1)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    color,
                    2,
                )

            else:
                print(f"Warning: Class index {cls} is out of range for classNames")

    # Resize the image to 1280x720 for display (adjust as needed)
    resized_img = cv2.resize(img, (1366, 768))

    # Display the image
    cv2.imshow("Image", resized_img)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release video capture and video writer
cap.release()

# Close all windows
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 Otherss, 24.8ms
# Speed: 3.5ms preprocess, 24.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.1ms
# Speed: 3.6ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.1ms
# Speed: 3.5ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.4ms
# Speed: 3.0ms preprocess, 16.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.1ms
# Speed: 4.1ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.7ms
# Speed: 3.7ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 14.0ms
# Speed: 3.3ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 14.2ms
# Speed: 3.0ms preprocess, 14.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.8ms
# Speed: 1.1ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 12.0ms
# Speed: 2.3ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 5.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 14.3ms
# Speed: 3.0ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 18.9ms
# Speed: 3.1ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.2ms
# Speed: 3.5ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 18.2ms
# Speed: 3.1ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.5ms
# Speed: 3.4ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 19.5ms
# Speed: 3.4ms preprocess, 19.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.5ms
# Speed: 6.4ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.2ms
# Speed: 3.4ms preprocess, 17.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.6ms
# Speed: 2.1ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.3ms
# Speed: 3.4ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.0ms
# Speed: 2.6ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 11.0ms
# Speed: 2.1ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 17.6ms
# Speed: 3.0ms preprocess, 17.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 3.2ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.6ms
# Speed: 3.3ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.5ms
# Speed: 2.4ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 14.8ms
# Speed: 4.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.2ms
# Speed: 3.6ms preprocess, 9.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Otherss, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.0ms
# Speed: 3.3ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 3.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## With Track

# %%
cap = cv2.VideoCapture(input_video_path)

# %%
track_history = defaultdict(lambda: [])

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    results = model.track(frame, persist=True)
    img = results[0].plot()

    # Check if there are any detected boxes
    if results[0].boxes is not None:
        boxes = results[0].boxes.xywh.cpu()

        # Check if track IDs are available
        if results[0].boxes.id is not None:
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Process each detected object
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))
                if len(track) > 90:
                    track.pop(0)
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))

                cv2.polylines(
                    img,
                    [points],
                    isClosed=False,
                    color=(230, 230, 230),
                    thickness=6,
                )

        else:
            print("No track IDs available")

    resized_img = cv2.resize(img, (1280, 720))

    # Display the image
    cv2.imshow("Image", resized_img)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 Otherss, 14.0ms
# Speed: 3.4ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 12.3ms
# Speed: 2.9ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.7ms
# Speed: 2.8ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.9ms
# Speed: 4.7ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.4ms
# Speed: 2.8ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.4ms
# Speed: 2.4ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.0ms
# Speed: 3.3ms preprocess, 17.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 15.7ms
# Speed: 3.0ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.1ms
# Speed: 3.5ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.7ms
# Speed: 3.5ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 17.4ms
# Speed: 5.8ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Otherss, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
