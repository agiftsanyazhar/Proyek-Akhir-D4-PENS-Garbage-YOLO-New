# %%
from ultralytics import YOLO
import cv2
import math
from collections import defaultdict
import numpy as np

# %% [markdown]
# ## Without Track

# %%
# # For Webcam
# cap = cv2.VideoCapture(0)

# For Video
input_video_path = "footage/phone/VID_20241014_104735.mp4"
cap = cv2.VideoCapture(input_video_path)

# %%
# Initialize the YOLO model
model = YOLO("runs/train/train5/weights/best.pt")

# %%
# Define class names
classNames = ["Others", "Plastic", "Straw", "Paper", "Tissue", "Bottle", "Beverage Carton Box", "Cigarette Pack"]

# Define colors for each class (adjust as needed)
class_colors = {
    "Others": (255, 0, 0),
    "Plastic": (255, 0, 128),
    "Straw": (255, 0, 255),
    "Paper": (179, 0, 255),
    "Tissue": (0, 255, 0),
    "Bottle": (0, 255, 255),
    "Beverage Carton Box": (0, 128, 255),
    "Cigarette Pack": (0, 0, 255),
}

# %%
while True:
    # Read a frame from the video
    success, img = cap.read()
    if not success:
        break

    # Perform object detection
    results = model(img, stream=True)

    # Process each result
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # Extract box coordinates and confidence
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            conf = math.ceil((box.conf[0] * 100)) / 100
            cls = int(box.cls[0])

            # Ensure the class index is within the range of classNames
            if cls < len(classNames):
                currentClass = classNames[cls]

                color = class_colors[currentClass]
                cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
                text = f"{currentClass} {conf}"
                cv2.putText(
                    img,
                    text,
                    (max(0, x1), max(35, y1)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    color,
                    2,
                )

            else:
                print(f"Warning: Class index {cls} is out of range for classNames")

    # Resize the image to 1280x720 for display (adjust as needed)
    resized_img = cv2.resize(img, (720, 1280))

    # Display the image
    cv2.imshow("Image", resized_img)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release video capture and video writer
cap.release()

# Close all windows
cv2.destroyAllWindows()
# Out:
# 0: 640x384 3 Plastics, 1 Straw, 20.1ms
# Speed: 3.1ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 2 Straws, 17.7ms
# Speed: 4.0ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Plastics, 1 Straw, 17.0ms
# Speed: 2.7ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 17.8ms
# Speed: 2.5ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 1 Straw, 17.2ms
# Speed: 3.6ms preprocess, 17.2ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 14.3ms
# Speed: 3.1ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 16.5ms
# Speed: 5.1ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Plastics, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Tissue, 16.3ms
# Speed: 3.2ms preprocess, 16.3ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 1 Tissue, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 1 Tissue, 16.5ms
# Speed: 3.4ms preprocess, 16.5ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 1 Tissue, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 1 Tissue, 13.8ms
# Speed: 2.9ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 1 Tissue, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 19.3ms
# Speed: 2.7ms preprocess, 19.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Straw, 16.0ms
# Speed: 3.5ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 1 Straw, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 13.9ms
# Speed: 3.4ms preprocess, 13.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 1 Tissue, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 1 Straw, 14.8ms
# Speed: 2.6ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Straw, 1 Tissue, 14.0ms
# Speed: 5.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Tissue, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Tissue, 14.2ms
# Speed: 3.5ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Tissue, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 3.1ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Tissue, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 1 Tissue, 14.3ms
# Speed: 4.8ms preprocess, 14.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.5ms
# Speed: 4.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 17.8ms
# Speed: 2.9ms preprocess, 17.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 3.4ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 1 Tissue, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 15.4ms
# Speed: 3.0ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.8ms
# Speed: 3.2ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 13.4ms
# Speed: 3.9ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.8ms
# Speed: 3.3ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.8ms
# Speed: 3.2ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Plastics, 14.4ms
# Speed: 2.6ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Plastics, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Tissue, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.8ms
# Speed: 3.2ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Plastics, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 1 Straw, 14.0ms
# Speed: 3.4ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Straw, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Plastic, 13.7ms
# Speed: 3.2ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.4ms
# Speed: 2.5ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 4.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 1.1ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.8ms
# Speed: 2.3ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 3.1ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.2ms
# Speed: 2.8ms preprocess, 14.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 3.2ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 3.3ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 3.4ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.3ms
# Speed: 4.0ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 5.7ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 3.3ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.1ms
# Speed: 3.4ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.9ms
# Speed: 3.2ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.8ms
# Speed: 2.6ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.1ms
# Speed: 3.8ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.2ms
# Speed: 5.0ms preprocess, 16.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.2ms
# Speed: 3.0ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 17.2ms
# Speed: 4.3ms preprocess, 17.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 21.1ms
# Speed: 2.5ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 13.0ms
# Speed: 2.4ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 13.6ms
# Speed: 2.9ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 4.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.9ms
# Speed: 2.5ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.0ms
# Speed: 3.6ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 2.5ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.9ms
# Speed: 3.2ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 3.2ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.0ms
# Speed: 3.2ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.3ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 4.1ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.1ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 3.3ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 4.7ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.3ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.3ms
# Speed: 3.4ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 20.5ms
# Speed: 3.0ms preprocess, 20.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 2.2ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 3.3ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.2ms
# Speed: 3.6ms preprocess, 16.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.3ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.0ms
# Speed: 2.2ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.6ms
# Speed: 3.8ms preprocess, 19.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.3ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.1ms
# Speed: 3.4ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.3ms
# Speed: 3.6ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.6ms
# Speed: 3.4ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 3.2ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.8ms
# Speed: 3.4ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 5.0ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 2.7ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Cigarette Pack, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 1.3ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 3.8ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.2ms
# Speed: 3.5ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.0ms
# Speed: 3.1ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 5.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.7ms
# Speed: 3.4ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.9ms
# Speed: 3.1ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.5ms
# Speed: 5.5ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 2.8ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.4ms
# Speed: 3.1ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.4ms
# Speed: 2.3ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 2.6ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.0ms
# Speed: 3.3ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 2.6ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# ## With Track

# %%
cap = cv2.VideoCapture(input_video_path)

# %%
track_history = defaultdict(lambda: [])

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    results = model.track(frame, persist=True)
    img = results[0].plot()

    # Check if there are any detected boxes
    if results[0].boxes is not None:
        boxes = results[0].boxes.xywh.cpu()

        # Check if track IDs are available
        if results[0].boxes.id is not None:
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Process each detected object
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))
                if len(track) > 90:
                    track.pop(0)
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))

                cv2.polylines(
                    img,
                    [points],
                    isClosed=False,
                    color=(230, 230, 230),
                    thickness=6,
                )

        else:
            print("No track IDs available")

    resized_img = cv2.resize(img, (1280, 720))

    # Display the image
    cv2.imshow("Image", resized_img)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 13.4ms
# Speed: 6.7ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 4.3ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 3.8ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 3.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.7ms
# Speed: 3.2ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.6ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.3ms
# Speed: 3.4ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 4.1ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.5ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 5.8ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 3.4ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 3.3ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 4.5ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 5.8ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 5.2ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 4.0ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 5.5ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 3.4ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 3.4ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 3.9ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 3.6ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 1 Plastic, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.9ms
# Speed: 3.1ms preprocess, 15.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 10.0ms
# Speed: 1.3ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.3ms
# Speed: 4.0ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.2ms
# Speed: 4.0ms preprocess, 15.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 14.8ms
# Speed: 4.6ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.1ms
# Speed: 4.1ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 14.5ms
# Speed: 2.6ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.9ms
# Speed: 4.4ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.3ms
# Speed: 3.1ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 15.9ms
# Speed: 4.4ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.1ms
# Speed: 3.7ms preprocess, 17.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 19.0ms
# Speed: 3.9ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.1ms
# Speed: 3.4ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.2ms
# Speed: 2.5ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.8ms
# Speed: 4.5ms preprocess, 17.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.2ms
# Speed: 3.1ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.5ms
# Speed: 2.3ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.0ms
# Speed: 4.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.9ms
# Speed: 3.3ms preprocess, 17.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.0ms
# Speed: 3.2ms preprocess, 17.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.2ms
# Speed: 2.3ms preprocess, 18.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.6ms
# Speed: 5.0ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.6ms
# Speed: 3.0ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.7ms
# Speed: 3.4ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.4ms
# Speed: 4.0ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.6ms
# Speed: 3.5ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 17.6ms
# Speed: 3.6ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 19.6ms
# Speed: 3.2ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 18.1ms
# Speed: 4.2ms preprocess, 18.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 18.8ms
# Speed: 3.3ms preprocess, 18.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.5ms
# Speed: 3.3ms preprocess, 19.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 18.3ms
# Speed: 2.9ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.4ms
# Speed: 2.8ms preprocess, 19.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.3ms
# Speed: 3.7ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.1ms
# Speed: 3.2ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 18.9ms
# Speed: 3.2ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 4.2ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.4ms
# Speed: 3.7ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.9ms
# Speed: 2.8ms preprocess, 19.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.4ms
# Speed: 3.4ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.5ms
# Speed: 3.5ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 19.7ms
# Speed: 3.0ms preprocess, 19.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.3ms
# Speed: 2.2ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 1 Paper, 21.4ms
# Speed: 2.6ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 4.4ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.9ms
# Speed: 2.6ms preprocess, 21.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.1ms
# Speed: 2.7ms preprocess, 21.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 2.3ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.9ms
# Speed: 2.4ms preprocess, 21.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.7ms
# Speed: 3.6ms preprocess, 20.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.8ms
# Speed: 3.0ms preprocess, 21.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.2ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 4.0ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.9ms
# Speed: 2.4ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 3.2ms preprocess, 21.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 3.3ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 4.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.1ms
# Speed: 2.5ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 6.3ms preprocess, 21.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 4.1ms preprocess, 20.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 3.4ms preprocess, 21.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.7ms
# Speed: 3.0ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 2.5ms preprocess, 20.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.7ms
# Speed: 3.1ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 4.5ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.3ms preprocess, 21.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 2.5ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.5ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 2.4ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 3.1ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.3ms preprocess, 21.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.1ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.9ms
# Speed: 2.9ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.2ms
# Speed: 6.3ms preprocess, 22.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 2.5ms preprocess, 21.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.8ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.6ms preprocess, 21.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 4.8ms preprocess, 21.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.1ms
# Speed: 3.2ms preprocess, 21.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.5ms
# Speed: 3.8ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.1ms
# Speed: 2.5ms preprocess, 22.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 4.2ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.7ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 3.3ms preprocess, 21.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 3.0ms preprocess, 20.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.8ms
# Speed: 3.0ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 4.8ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 6.1ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.8ms
# Speed: 3.4ms preprocess, 21.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 2.6ms preprocess, 21.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.4ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.2ms
# Speed: 1.8ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 2.7ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 5.7ms preprocess, 21.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.8ms preprocess, 21.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.5ms
# Speed: 5.1ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 2.8ms preprocess, 21.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 2.5ms preprocess, 22.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 3.1ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 22.0ms
# Speed: 6.9ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 21.8ms
# Speed: 3.7ms preprocess, 21.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 3.2ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 5.0ms preprocess, 21.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 3.0ms preprocess, 21.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 3.5ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 2.1ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.5ms preprocess, 21.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 3.2ms preprocess, 20.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 2.2ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.8ms
# Speed: 2.7ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 3.2ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.5ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 2.7ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 3.1ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 4.1ms preprocess, 20.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 2.5ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 3.5ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.9ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.1ms
# Speed: 3.7ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 5.3ms preprocess, 21.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 2.1ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 2.4ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.0ms
# Speed: 3.4ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.7ms
# Speed: 2.4ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 5.5ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.3ms
# Speed: 2.1ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 3.4ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.6ms
# Speed: 3.4ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.9ms
# Speed: 4.1ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 22.4ms
# Speed: 2.4ms preprocess, 22.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 6.6ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.3ms
# Speed: 3.1ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.2ms
# Speed: 2.3ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.0ms
# Speed: 3.3ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.4ms
# Speed: 3.1ms preprocess, 21.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 20.6ms
# Speed: 3.8ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.5ms
# Speed: 2.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 1 Paper, 21.9ms
# ...
# No track IDs available
#
# 0: 384x640 (no detections), 19.6ms
# Speed: 2.2ms preprocess, 19.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 3.5ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 1 Plastic, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# No track IDs available
#
# 0: 384x640 1 Plastic, 14.7ms
# Speed: 3.2ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.3ms
# Speed: 3.8ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.9ms
# Speed: 3.5ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.0ms
# Speed: 2.7ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 13.8ms
# Speed: 3.8ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 15.0ms
# Speed: 6.2ms preprocess, 15.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.3ms
# Speed: 3.4ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.5ms
# Speed: 4.2ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.3ms
# Speed: 3.4ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.6ms
# Speed: 3.2ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 16.8ms
# Speed: 3.4ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 16.9ms
# Speed: 2.6ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.8ms
# Speed: 3.0ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.7ms
# Speed: 3.1ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.1ms
# Speed: 2.4ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.4ms
# Speed: 3.0ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.0ms
# Speed: 3.4ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.1ms
# Speed: 5.3ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.4ms
# Speed: 3.0ms preprocess, 19.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.0ms
# Speed: 3.2ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.2ms
# Speed: 3.0ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.5ms
# Speed: 3.4ms preprocess, 19.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.4ms
# Speed: 3.5ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.1ms
# Speed: 4.0ms preprocess, 19.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 18.4ms
# Speed: 3.3ms preprocess, 18.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.1ms
# Speed: 3.1ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.0ms
# Speed: 6.2ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.3ms
# Speed: 4.6ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.1ms
# Speed: 4.2ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.6ms
# Speed: 4.6ms preprocess, 20.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.9ms
# Speed: 4.0ms preprocess, 20.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 19.6ms
# Speed: 2.9ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.7ms
# Speed: 2.6ms preprocess, 20.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.3ms
# Speed: 3.5ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.1ms
# Speed: 3.6ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.4ms
# Speed: 5.1ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.4ms
# Speed: 2.0ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 2.7ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.1ms
# Speed: 2.3ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.0ms
# Speed: 3.5ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.3ms
# Speed: 2.3ms preprocess, 21.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.8ms
# Speed: 3.5ms preprocess, 20.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.8ms
# Speed: 3.0ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 2.5ms preprocess, 21.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.7ms
# Speed: 4.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 3.3ms preprocess, 21.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 3.3ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 6.0ms preprocess, 21.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.1ms
# Speed: 2.3ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.1ms
# Speed: 2.4ms preprocess, 22.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.2ms
# Speed: 3.6ms preprocess, 22.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.6ms
# Speed: 5.3ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.4ms
# Speed: 3.3ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.8ms
# Speed: 3.7ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 22.2ms
# Speed: 4.0ms preprocess, 22.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.8ms
# Speed: 3.0ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.9ms
# Speed: 3.1ms preprocess, 21.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.4ms
# Speed: 3.3ms preprocess, 21.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.5ms
# Speed: 3.1ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.6ms
# Speed: 2.6ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.5ms
# Speed: 5.9ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.1ms
# Speed: 3.5ms preprocess, 21.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 20.7ms
# Speed: 3.0ms preprocess, 20.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 21.2ms
# Speed: 3.4ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
