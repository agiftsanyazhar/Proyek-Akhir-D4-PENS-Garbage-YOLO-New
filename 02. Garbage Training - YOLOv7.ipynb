# %% [markdown]
# ## 1. Install Dependencies (Python 3.10.11)

# %%
# !pip install opencv-python==4.10.0.84 labelme==5.5.0 ultralytics==8.2.48
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting labelme
#   Downloading labelme-5.5.0.tar.gz (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      --- ------------------------------------ 0.1/1.4 MB 3.2 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.4/1.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------- ------------- 1.0/1.4 MB 7.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 9.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ultralytics
#   Using cached ultralytics-8.2.48-py3-none-any.whl.metadata (41 kB)
# Collecting numpy>=1.21.2 (from opencv-python)
#   Using cached numpy-2.0.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting gdown (from labelme)
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting imgviz>=1.7.5 (from labelme)
#   Using cached imgviz-1.7.5-py3-none-any.whl
# Collecting matplotlib (from labelme)
#   Using cached matplotlib-3.9.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting natsort>=7.1.0 (from labelme)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting onnxruntime!=1.16.0,>=1.14.1 (from labelme)
#   Downloading onnxruntime-1.18.1-cp310-cp310-win_amd64.whl.metadata (4.5 kB)
# Collecting Pillow>=2.8 (from labelme)
#   Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting PyYAML (from labelme)
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting qtpy!=1.11.2 (from labelme)
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting scikit-image (from labelme)
#   Using cached scikit_image-0.24.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting termcolor (from labelme)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting PyQt5!=5.15.3,!=5.15.4 (from labelme)
#   Using cached PyQt5-5.15.10-cp37-abi3-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: colorama in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from labelme) (0.4.6)
# Collecting numpy>=1.21.2 (from opencv-python)
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Using cached scipy-1.14.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.3.1-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.18.1-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from ultralytics) (6.0.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->labelme)
#   Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->labelme)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->labelme)
#   Using cached fonttools-4.53.0-cp310-cp310-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->labelme)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from matplotlib->labelme) (24.1)
# Collecting pyparsing>=2.3.1 (from matplotlib->labelme)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from matplotlib->labelme) (2.9.0.post0)
# Collecting coloredlogs (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting sympy (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Using cached PyQt5_sip-12.13.0-cp310-cp310-win_amd64.whl.metadata (524 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Collecting charset-normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch>=1.8.0->ultralytics)
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting beautifulsoup4 (from gdown->labelme)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting imageio>=2.33 (from scikit-image->labelme)
#   Using cached imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->labelme)
#   Using cached tifffile-2024.6.18-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->labelme)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Using cached tbb-2021.13.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.16.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown->labelme)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->labelme)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached ultralytics-8.2.48-py3-none-any.whl (793 kB)
# Using cached matplotlib-3.9.0-cp310-cp310-win_amd64.whl (8.0 MB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Downloading onnxruntime-1.18.1-cp310-cp310-win_amd64.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.9/5.6 MB 19.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.6 MB 17.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.6 MB 17.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.2/5.6 MB 17.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.9/5.6 MB 16.8 MB/s eta 0:00:01
#    --------------------------------- ------ 4.7/5.6 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 16.2 MB/s eta 0:00:00
# Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached PyQt5-5.15.10-cp37-abi3-win_amd64.whl (6.8 MB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached scipy-1.14.0-cp310-cp310-win_amd64.whl (44.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torch-2.3.1-cp310-cp310-win_amd64.whl (159.8 MB)
# Using cached torchvision-0.18.1-cp310-cp310-win_amd64.whl (1.2 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached scikit_image-0.24.0-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached imageio-2.34.2-py3-none-any.whl (313 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.13.0-py3-none-win_amd64.whl (286 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Using cached PyQt5_sip-12.13.0-cp310-cp310-win_amd64.whl (78 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tifffile-2024.6.18-py3-none-any.whl (226 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl (426 kB)
#    ---------------------------------------- 0.0/426.9 kB ? eta -:--:--
#    --------------------------------------- 426.9/426.9 kB 13.4 MB/s eta 0:00:00
# Using cached sympy-1.12.1-py3-none-any.whl (5.7 MB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: labelme
#   Building wheel for labelme (pyproject.toml): started
#   Building wheel for labelme (pyproject.toml): finished with status 'done'
#   Created wheel for labelme: filename=labelme-5.5.0-py3-none-any.whl size=1437521 sha256=2980b5b71df231b80b4b19a715fbe4e13bf49bcf3cf3a1e9804faebb3bbde3d2
#   Stored in directory: c:\users\agift\appdata\local\pip\cache\wheels\44\3a\5e\487d2768ccb5f2411334ac0f3fa7265c94decca9fd94f64d6b
# Successfully built labelme
# Installing collected packages: tbb, pytz, pyreadline3, PyQt5-Qt5, py-cpuinfo, mpmath, intel-openmp, flatbuffers, urllib3, tzdata, tqdm, termcolor, sympy, soupsieve, qtpy, PyYAML, PySocks, PyQt5-sip, pyparsing, protobuf, Pillow, numpy, networkx, natsort, mkl, MarkupSafe, lazy-loader, kiwisolver, idna, humanfriendly, fsspec, fonttools, filelock, cycler, charset-normalizer, certifi, tifffile, scipy, requests, PyQt5, pandas, opencv-python, jinja2, imageio, contourpy, coloredlogs, beautifulsoup4, torch, scikit-image, onnxruntime, matplotlib, ultralytics-thop, torchvision, seaborn, imgviz, gdown, ultralytics, labelme
# Successfully installed MarkupSafe-2.1.5 Pillow-10.4.0 PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 PySocks-1.7.1 PyYAML-6.0.1 beautifulsoup4-4.12.3 certifi-2024.6.2 charset-normalizer-3.3.2 coloredlogs-15.0.1 contourpy-1.2.1 cycler-0.12.1 filelock-3.15.4 flatbuffers-24.3.25 fonttools-4.53.0 fsspec-2024.6.1 gdown-5.2.0 humanfriendly-10.0 idna-3.7 imageio-2.34.2 imgviz-1.7.5 intel-openmp-2021.4.0 jinja2-3.1.4 kiwisolver-1.4.5 labelme-5.5.0 lazy-loader-0.4 matplotlib-3.9.0 mkl-2021.4.0 mpmath-1.3.0 natsort-8.4.0 networkx-3.3 numpy-1.26.4 onnxruntime-1.18.1 opencv-python-4.10.0.84 pandas-2.2.2 protobuf-5.27.2 py-cpuinfo-9.0.0 pyparsing-3.1.2 pyreadline3-3.4.1 pytz-2024.1 qtpy-2.4.1 requests-2.32.3 scikit-image-0.24.0 scipy-1.14.0 seaborn-0.13.2 soupsieve-2.5 sympy-1.12.1 tbb-2021.13.0 termcolor-2.4.0 tifffile-2024.6.18 torch-2.3.1 torchvision-0.18.1 tqdm-4.66.4 tzdata-2024.1 ultralytics-8.2.48 ultralytics-thop-2.0.0 urllib3-2.2.2

# %%
# !pip3 install torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.3.0
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.3.0%2Bcu118-cp310-cp310-win_amd64.whl (2673.0 MB)
# Collecting torchvision==0.18.0
#   Using cached https://download.pytorch.org/whl/cu118/torchvision-0.18.0%2Bcu118-cp310-cp310-win_amd64.whl (4.9 MB)
# Collecting torchaudio==2.3.0
#   Using cached https://download.pytorch.org/whl/cu118/torchaudio-2.3.0%2Bcu118-cp310-cp310-win_amd64.whl (4.0 MB)
# Requirement already satisfied: filelock in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (4.12.2)
# Requirement already satisfied: sympy in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (1.12.1)
# Requirement already satisfied: networkx in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (3.3)
# Requirement already satisfied: jinja2 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (3.1.4)
# Requirement already satisfied: fsspec in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torch==2.3.0) (2021.4.0)
# Requirement already satisfied: numpy in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torchvision==0.18.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from torchvision==0.18.0) (10.4.0)
# Requirement already satisfied: intel-openmp==2021.* in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from jinja2->torch==2.3.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage yolo\.venv\lib\site-packages (from sympy->torch==2.3.0) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1
#     Uninstalling torch-2.3.1:
#       Successfully uninstalled torch-2.3.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.1
#     Uninstalling torchvision-0.18.1:
#       Successfully uninstalled torchvision-0.18.1
# Successfully installed torch-2.3.0+cu118 torchaudio-2.3.0+cu118 torchvision-0.18.0+cu118

# %%
# !nvidia-smi
# Out:
# Thu Jul  4 17:14:11 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.44                 Driver Version: 552.44         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P3             14W /   71W |       0MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ------------
# absl-py                 2.1.0
# asttokens               2.4.1
# beautifulsoup4          4.12.3
# cachetools              5.3.3
# certifi                 2024.6.2
# charset-normalizer      3.3.2
# colorama                0.4.6
# coloredlogs             15.0.1
# comm                    0.2.2
# contourpy               1.2.1
# cvzone                  1.6.1
# cycler                  0.12.1
# debugpy                 1.8.2
# decorator               5.1.1
# exceptiongroup          1.2.1
# executing               2.0.1
# filelock                3.15.4
# filterpy                1.4.5
# flatbuffers             24.3.25
# fonttools               4.53.0
# fsspec                  2024.6.1
# gdown                   5.2.0
# google-auth             2.31.0
# google-auth-oauthlib    0.4.6
# grpcio                  1.64.1
# humanfriendly           10.0
# idna                    3.7
# imageio                 2.34.2
# imgviz                  1.7.5
# intel-openmp            2021.4.0
# ipykernel               6.29.5
# ipython                 8.26.0
# jedi                    0.19.1
# Jinja2                  3.1.4
# jupyter_client          8.6.2
# jupyter_core            5.7.2
# kiwisolver              1.4.5
# labelme                 5.5.0
# labelme2yolo            0.1.7
# lapx                    0.5.9.post1
# lazy_loader             0.4
# Markdown                3.6
# markdown-it-py          3.0.0
# MarkupSafe              2.1.5
# matplotlib              3.9.0
# matplotlib-inline       0.1.7
# mdurl                   0.1.2
# mkl                     2021.4.0
# mpmath                  1.3.0
# natsort                 8.4.0
# nest-asyncio            1.6.0
# networkx                3.3
# numpy                   1.26.4
# oauthlib                3.2.2
# onnxruntime             1.18.1
# opencv-python           4.10.0.84
# packaging               24.1
# pandas                  2.2.2
# parso                   0.8.4
# pillow                  10.2.0
# pip                     24.1.1
# platformdirs            4.2.2
# prompt_toolkit          3.0.47
# protobuf                5.27.2
# psutil                  6.0.0
# pure-eval               0.2.2
# py-cpuinfo              9.0.0
# pyasn1                  0.6.0
# pyasn1_modules          0.4.0
# Pygments                2.18.0
# pyparsing               3.1.2
# PyQt5                   5.15.10
# PyQt5-Qt5               5.15.2
# PyQt5-sip               12.13.0
# pyreadline3             3.4.1
# PySocks                 1.7.1
# python-dateutil         2.9.0.post0
# pytz                    2024.1
# pywin32                 306
# PyYAML                  6.0.1
# pyzmq                   26.0.3
# QtPy                    2.4.1
# requests                2.32.3
# requests-oauthlib       2.0.0
# rich                    13.7.1
# rsa                     4.9
# scikit-image            0.24.0
# scipy                   1.14.0
# seaborn                 0.13.2
# setuptools              65.5.0
# six                     1.16.0
# soupsieve               2.5
# stack-data              0.6.3
# sympy                   1.12.1
# tbb                     2021.13.0
# tensorboard             2.8.0
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.1
# termcolor               2.4.0
# tifffile                2024.6.18
# torch                   2.3.0+cu118
# torchaudio              2.3.0+cu118
# torchvision             0.18.0+cu118
# tornado                 6.4.1
# tqdm                    4.66.4
# traitlets               5.14.3
# typing_extensions       4.12.2
# tzdata                  2024.1
# ultralytics             8.2.48
# ultralytics-thop        2.0.0
# urllib3                 2.2.2
# wcwidth                 0.2.13
# Werkzeug                3.0.3
# wheel                   0.43.0

# %% [markdown]
# ## 2. Custom Data Training

# %%
import os
import torch

# %%
# Define the file paths
file_paths = ["dataset/labels/train.cache", "dataset/labels/val.cache"]

# Iterate through each file path
for file_path in file_paths:
    # Check if the file exists using os.path.exists
    if os.path.exists(file_path):
        # Delete the file using os.remove
        os.remove(file_path)
        print(f"Deleted file: {file_path}")
    else:
        print(f"File not found: {file_path}")
# Out:
# File not found: dataset/labels/train.cache
# Deleted file: dataset/labels/val.cache

# %%
# Define training parameters
train_path = "yolov7/train.py"
weight_path = "yolov7/yolov7.pt"
cfg = "yolov7/cfg/training/yolov7.yaml"
data_path = "dataset/dataset.yaml"
hyp = "yolov7/data/hyp.scratch.p5.yaml"
epochs = 100
batch = 32
workers = 3

# %%
# Enable mixed precision training if supported
if torch.cuda.is_available():
    torch.backends.cudnn.benchmark = True  # Enable CuDNN auto-tuner
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# Construct the command
command = (
    f"python {train_path} --weights {weight_path} --cfg {cfg} "
    f"--data {data_path} --hyp {hyp} --epochs {epochs} "
    f"--batch-size {batch} --workers {workers} --device {device}"
)

# Run the command
print(command)
# Out:
# python yolov7/train.py --weights yolov7/yolov7.pt --cfg yolov7/cfg/training/yolov7.yaml --data dataset/dataset.yaml --hyp yolov7/data/hyp.scratch.p5.yaml --epochs 100 --batch-size 32 --workers 3 --device cuda
