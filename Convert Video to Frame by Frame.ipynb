# %%
import cv2
import os
import glob
import re

# %%
# Path to the video file
video_path = "footage/testing/phone/VID_20241117_175833.mp4"
output_name = "VID_20241117_175833"
output_folder = "images/all in one"

# Create the output directory if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
# Find the highest count in the existing files
existing_files = glob.glob(os.path.join(output_folder, "*.jpg"))
counts = [int(re.search(r"(\d+)\.jpg$", file).group(1)) for file in existing_files]

if len(counts) == 0:
    start_count = 0
else:
    start_count = max(counts) + 1

# %%
# # Open the video file
# vidcap = cv2.VideoCapture(video_path)
# if not vidcap.isOpened():
#     print("Error: Could not open video.")
#     exit()

# count = start_count
# while vidcap.isOpened():
#     success, image = vidcap.read()
#     if not success:
#         break

#     # Construct the output file path
#     output_file = os.path.join(output_folder, f"{output_name}_{count}.jpg")

#     # Save the frame as an image file
#     cv2.imwrite(output_file, image)

#     count += 1

# # Release the video capture object
# vidcap.release()

# %%
# Open the video file
vidcap = cv2.VideoCapture(video_path)
if not vidcap.isOpened():
    print("Error: Could not open video.")
    exit()

frame_interval = 3
count = start_count
frame_number = 0

while vidcap.isOpened():
    success, image = vidcap.read()
    if not success:
        break

    if frame_number % frame_interval == 0:
        output_file = os.path.join(output_folder, f"{output_name}_{count}.jpg")
        cv2.imwrite(output_file, image)
        count += 1

    frame_number += 1

# Release the video capture object
vidcap.release()
